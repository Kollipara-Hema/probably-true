# %% [markdown]
# # 🎚️ Chapter 08 · Confidence Intervals & the Bootstrap
#
# *Book I — Statistics*
#
# ## 🚧 Coming soon
#
# This chapter is in production. It will cover:
#
# CIs from CLT, bootstrap principle.
#
# ## What's planned for this notebook
#
# - Math derivations from first principles
# - Python implementation using `numpy` and `matplotlib`
# - Animations showing the algorithm/concept converging
# - Real datasets where applicable
# - Worked example with code you can modify
#
# ## Follow along
#
# The interactive chapter for this topic will live at:
# [https://probably-true.vercel.app/chapters/confidence-intervals-bootstrap/](https://probably-true.vercel.app/chapters/confidence-intervals-bootstrap/)
#
# For now, head back to the [chapters that are already built](../intro.html).
