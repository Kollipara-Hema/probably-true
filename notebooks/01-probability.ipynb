# %% [markdown]
# # 🎲 Chapter 01 · Probability
#
# *Book I — Statistics*
#
# > 🎮 The interactive chapter for this topic is at [https://probably-true.vercel.app/chapters/probability/](https://probably-true.vercel.app/chapters/probability/). This notebook covers the same material with **math derivations, code, and matplotlib animations**.
#
# ## What this notebook covers
#
# Chance, sample space, independence.
#
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from celluloid import Camera
from IPython.display import HTML

np.random.seed(0)
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %% [markdown]
# ## The setup
#
# *[This notebook is a stub — derivations, code, and animations to follow. The interactive chapter above is the polished version. This page will fill in over time.]*

# %% [markdown]
# ## Why both surfaces?
#
# The interactive chapter is for **building intuition** — drag, click, see. This notebook is for **seeing the math** — derivations, code, animations of the algorithm converging.
#
# If you're reading this and want to see the visual story first, head to the interactive chapter linked above. If you've already seen it and want to know what's *actually happening*, you're in the right place.
